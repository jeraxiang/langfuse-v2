# %%
LANGFUSE_PUBLIC_KEY = "pk-lf-be7ee4cb-12c8-4c14-825e-a564da8157ca"
LANGFUSE_SECRET_KEY = "sk-lf-81e0768d-8a19-4458-9375-931e6ef1fb3e"
LANGFUSE_HOSTNAME = "https://langfuse.dev.jera-stg.com"

# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# Clear existing handlers to avoid duplicate logs
if logger.hasHandlers():
    logger.handlers.clear()

# Add a handler to display log in notebook directly
handler = logging.StreamHandler()
handler.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

logger.addHandler(handler)

# %%
import os
import pandas as pd
import datetime as dt
from typing import List, Dict
from langfuse import Langfuse
import tempfile

# helper function
def pydantic_list_to_dataframe(pydantic_list):
    """
    Convert a list of pydantic objects to a pandas dataframe.
    """
    data = []
    for item in pydantic_list:
        data.append(item.dict())
    return pd.DataFrame(data)


def convert_to_utc(date_str: str, date_type: str, local_tz=dt.timezone(dt.timedelta(hours=9))):
    local_date = dt.datetime.strptime(date_str, "%Y-%m-%d")  # Convert string to datetime
    local_date = dt.datetime(local_date.year, local_date.month, local_date.day, 
                                0, 0, 0, 0, tzinfo=local_tz)  # Set time to 00:00:00
    if date_type == 'to':
        local_date = local_date - dt.timedelta(microseconds=1) # End of yesterday
    return local_date.astimezone(dt.timezone.utc)  # Convert to UTC

def get_timestamps(from_timestamp=None, to_timestamp=None, local_tz=dt.timezone(dt.timedelta(hours=9))):

    if not from_timestamp:
        from_timestamp = dt.datetime.strftime(dt.datetime.now() - dt.timedelta(days=1), "%Y-%m-%d")
    from_timestamp = convert_to_utc(from_timestamp, date_type='from', local_tz=local_tz)

    if not to_timestamp:
        to_timestamp = dt.datetime.strftime(dt.datetime.now(), "%Y-%m-%d")
    else:
        to_timestamp = dt.datetime.strftime(dt.datetime.strptime(to_timestamp, "%Y-%m-%d") + dt.timedelta(days=1), "%Y-%m-%d")
    to_timestamp = convert_to_utc(to_timestamp, date_type='to', local_tz=local_tz)

    return from_timestamp, to_timestamp

def expend_metadata(df, metadata_keys: List[str] | None = None):
        # Select specific keys to extract
        # metadata_keys = ['channel', 'user_email', 'department_name', 'azure_user_id', 'question_uuid', 'costs']

        if metadata_keys is None or metadata_keys == []:
            # Convert None/NaN to an empty dictionary before expanding
            df_expanded = df['metadata'].apply(lambda x: pd.Series(x) if isinstance(x, dict) else pd.Series(dtype='object'))

            # Concatenate original DataFrame (excluding 'metadata') with expanded columns
            df = pd.concat([df, df_expanded], axis=1)
        else:
            # Create new columns with selected keys
            for key in metadata_keys:
                df[key] = df['metadata'].apply(lambda x: x.get(key, None) if isinstance(x, dict) else None)  # Check if x is a dict

        # Drop the original 'metadata' column if not needed
        df = df.drop(columns=['metadata'])
        return df

def convert_to_jst(utc_dt):
    # Original datetime in UTC
    # utc_time = dt.datetime.fromisoformat('2025-03-15 15:00:00+00:00')

    # Convert to JST (UTC+9)
    jst_time = utc_dt.astimezone(dt.timezone(dt.timedelta(hours=9)))

    return jst_time

class LangfuseAPI(object):
    def __init__(self, public_key: str, secret_key: str, host: str):
        self.langfuse = Langfuse(public_key = public_key, secret_key = secret_key, host = host)

    def fetch_traces(
            self, 
            limit: int, 
            page: int, 
            user_id: str | None = None, 
            from_timestamp: str | None = None, 
            to_timestamp: str | None =None, 
            max_traces: int | None = None,
            metadata_keys: List[str] | None = None  # default keys to extract
            ):

        from_timestamp, to_timestamp = get_timestamps(from_timestamp, to_timestamp)
        logger.info(f"Collect data from JST {convert_to_jst(from_timestamp)} to {convert_to_jst(to_timestamp)}")
        # logger.debug(f"Collect data from uTC {from_timestamp} to {to_timestamp}")
        all_traces = []
        while True:
            # logger.debug(f"Page#{page}")
            traces = self.langfuse.fetch_traces(limit=limit, page=page, user_id=user_id, from_timestamp=from_timestamp, to_timestamp=to_timestamp)
            all_traces.extend(traces.data)

            if len(traces.data) == 0:
                logger.info("No more traces found.")
                break

            if page % 10 == 0:
                logger.info(f"Page#{page}, {traces.data[0].timestamp} ~ {traces.data[-1].timestamp}")

            if len(traces.data) < limit:
                logger.info("All traces have been collected as the number of records is less than limit per page.")
                break
            
            if max_traces is not None and len(all_traces) >= max_traces:
                logger.info("The number of traces has been collected exceeds the total limit")
                break
            
            page += 1
        
        logger.info(f"Retrieved {len(all_traces)} traces.")
        all_traces_df = pydantic_list_to_dataframe(all_traces)

        if len(all_traces) > 0 and 'metadata' in all_traces_df.columns:
            all_traces_df = expend_metadata(all_traces_df, metadata_keys)
        return all_traces_df

def extract_question_answer(df):
    # Modified extraction logic
    df = df.copy()
    df['question'] = df['input'].apply(lambda x: x.get('question') if isinstance(x, dict) else None)
    df['final_answer'] = df['output'].apply(lambda x: x.get('final_answer') if isinstance(x, dict) else None)
    return df

def mapping_service_id_to_name(df, mapping_dict):
    # Map caller_id to Name
    df = df.copy()
    df['service'] = df['business_service'].map(mapping_dict)
    return df

def mapping_service_id_to_category(df, mapping_dict):
    # Map caller_id to Name
    df = df.copy()
    df['category'] = df['business_service'].map(mapping_dict)
    return df

def mapping_service_id_incident_creation(df, mapping_dict):
    df = df.copy()
    df['is_incident_creation'] = df['business_service'].map(mapping_dict) == "incident creation"
    return df

def extract_ids_from_intput(df):
    # Modified extraction logic
    df = df.copy()
    df['question_uuid'] = df['input'].apply(lambda x: x.get('question_uuid') if isinstance(x, dict) else None)
    df['conversation_uuid'] = df['input'].apply(lambda x: x.get('conversation_uuid') if isinstance(x, dict) else None)
    return df

from dotenv import load_dotenv
load_dotenv()

from src.blob_storage import BlobStorageHandler

def upload_to_blob(project:str, container_name, from_file_path: str, to_file_path: str | None = None, overwrite: bool = False):
    conn_str = os.environ[f"{project}_CONNECTION_STRING_PROD"]
    bsh = BlobStorageHandler(conn_str=conn_str, container_name=container_name)

    if to_file_path is None:
        file_name = os.path.basename(from_file_path)
        to_file_path = os.path.join(file_name)

    if bsh.blob_exists(to_file_path) and not overwrite:
        logger.info(f"`{to_file_path}` already exists in {container_name}.")
    else:
        bsh.upload_file(from_file_path, to_file_path, overwrite)
        logger.info(f"`{to_file_path}` uploaded to blob {container_name}.")
        
def load_from_blob(project:str, container_name, from_file_path: str):
    conn_str = os.environ[f"{project}_CONNECTION_STRING_PROD"]
    bsh = BlobStorageHandler(conn_str=conn_str, container_name=container_name)

    if not bsh.blob_exists(from_file_path):
        logger.info(f"`{from_file_path}` does not exist in {container_name}.")
        return None
    else:
        # Create a temporary directory
        with tempfile.TemporaryDirectory() as tmpdir:
            file_name = from_file_path.split("/")[-1]
            to_file_path = os.path.join(tmpdir, file_name)
            bsh.download_file(from_file_path, to_file_path)
            logger.info(f"save data to temporary place`{to_file_path}`.")
            df = pd.read_csv(to_file_path)
            return df

def conver_to_yyyymm(df, datetime_col:str):
    df = df.copy()

    df[datetime_col] = pd.to_datetime(df[datetime_col], format='mixed', utc=True)
    # 3. Convert to JST (UTC+9)
    df[datetime_col] = df[datetime_col].dt.tz_convert('Asia/Tokyo')

    # Step 3: Standardize JST timestamp format as ISO8601 string
    # df[datetime_col] = df[datetime_col].dt.strftime('%Y-%m-%dT%H:%M:%S.%f%z')

    # 4. Create year-month column
    df['year_month'] = df[datetime_col].dt.strftime('%Y-%m')

    # Step 4: Convert JST timestamp to ISO format string (optional: overwrite or add new column)
    df[datetime_col] = df[datetime_col].dt.strftime('%Y-%m-%dT%H:%M:%S.%f%z')
    
    return df

# answer_df = pd.read_csv(answer_tmp_fpath)

import tempfile

def save_data(df, project: str, container: str, overwrite: bool = False):
    df_new = df.copy()
    df_new = conver_to_yyyymm(df_new, 'timestamp')
    for month, group in df_new.groupby('year_month'):
        group.drop(columns=['year_month'], inplace=True)  # optional
        logger.info(f"New data: {len(group)}")
        # Create a temporary file
        with tempfile.NamedTemporaryFile(mode='w+', suffix='.csv', delete=True) as tmp:

            # read year_month from blob
            df_old = load_from_blob(project, container, f"{month}.csv")
            if df_old is not None:
                logger.info(f"Find {len(df_old)} rows data of {month} in Blob.")

                all_exist = group['id'].isin(df_old['id']).all()
                if all_exist:
                    if not overwrite:
                        logger.warning(f"All new data already existing, will not overwrite.")
                        continue
                    else:
                        logger.warning(f"Overwrite all.")
                        df_old = df_old[~df_old['id'].isin(group['id'])]
                else:
                    if not overwrite:
                        logger.warning(f"Will not overwrite any old data, but remove new data if they are already existing.")
                        group = group[~group['id'].isin(df_old['id'])]
                        logger.info(f"remaining {len(group)} new data.")
                    else:
                        logger.warning(f"Overwrite old data if have.")
                        df_old = df_old[~df_old['id'].isin(group['id'])]
                        logger.info(f"remaining {len(df_old)} old data.")
                # else:
                #     logger.warning(f"All are new data.")
                    
                result = pd.concat([df_old, group], ignore_index=True).sort_values(["timestamp"], ascending=False)
                logger.info(f"Merged data: {len(result)}")
                
            else:
                logger.info(f"No {month} data, will directly save new data to blob")
                result = group.copy()

            # Save the DataFrame to CSV
            result.to_csv(tmp.name, index=False, quoting=1)
            logger.info(f'Temporary {container} CSV saved at: {tmp.name}')
            upload_to_blob(project, container, tmp.name, f"{month}.csv", True)
    
    return True

# %% [markdown]
# # Collection new data

# %%
langfuseapi = LangfuseAPI(LANGFUSE_PUBLIC_KEY, LANGFUSE_SECRET_KEY, LANGFUSE_HOSTNAME)

limit = 100  # Adjust as needed to balance performance and data retrieval.
page = 1
max_traces = None
# user_id = "余 翔(Xiang Yu)"
user_id = None

from_timestamp = None
to_timestamp = None

from_timestamp = "2025-04-14"
to_timestamp = "2025-04-14"

metadata_keys = None

trace_df = langfuseapi.fetch_traces(
    limit=limit, 
    page=page, 
    user_id=user_id, 
    from_timestamp=from_timestamp, 
    to_timestamp=to_timestamp,
    metadata_keys=metadata_keys
)
trace_df = trace_df[["id", "timestamp", "name", "userId", "department_name", 'service_category', "service_name","question_id", 'incident_category','input', 'output']]
# Out:
# 2025-04-15 10:36:35,793 - root - INFO - Collect data from JST 2025-04-14 00:00:00+09:00 to 2025-04-14 23:59:59.999999+09:00
# 2025-04-15 10:36:36,158 - root - INFO - All traces have been collected as the number of records is less than limit per page.
# 2025-04-15 10:36:36,159 - root - INFO - Retrieved 192 traces.

# %% [markdown]
# ## Answer

# %%
trace_df_answer = trace_df[trace_df["name"] == "HDA_Answer"].copy()
trace_df_answer = extract_question_answer(trace_df_answer)
trace_df_answer = trace_df_answer.drop(columns=['input', 'output'])

# %%
save_data(trace_df_answer, 'NOVA', 'answer', False)
# Out:
# 2025-04-15 10:36:44,666 - root - INFO - New data: 69
# 2025-04-15 10:36:44,796 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/answer/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '16e08da8-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:36:44,922 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '677528'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:03:21 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF88838CB7F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'cb12393d-c01e-0009-42a6-ad065e000000'
#     'x-ms-client-request-id': '16e08da8-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:36:44 GMT'
# 2025-04-15 10:36:44,927 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/answer/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '16e08da9-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:36:45,021 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '677528'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:03:21 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF88838CB7F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a674d2d5-501e-0079-47a6-adbfa9000000'
#     'x-ms-client-request-id': '16e08da9-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:36:44 GMT'
# 2025-04-15 10:36:45,024 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/answer/2025-04.csv'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '16e08daa-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:36:45,138 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '677528'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:03:21 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF88838CB7F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '85b83a97-f01e-0094-3fa6-adf4e4000000'
#     'x-ms-client-request-id': '16e08daa-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:36:44 GMT'
# 2025-04-15 10:36:45,271 - root - INFO - save data to temporary place`/tmp/tmpmvlxphfj/2025-04.csv`.
# 2025-04-15 10:36:45,284 - root - INFO - Find 578 rows data of 2025-04 in Blob.
# 2025-04-15 10:36:45,287 - root - WARNING - Will not overwrite any old data, but remove new data if they are already existing.
# 2025-04-15 10:36:45,290 - root - INFO - remaining 69 new data.
# 2025-04-15 10:36:45,293 - root - INFO - Merged data: 647
# 2025-04-15 10:36:45,306 - root - INFO - Temporary answer CSV saved at: /tmp/tmp5v7_entx.csv
# 2025-04-15 10:36:45,309 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/answer/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '16e08dab-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:36:45,401 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '677528'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:03:21 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF88838CB7F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'f1dfc4ec-b01e-002c-0fa6-adaf22000000'
#     'x-ms-client-request-id': '16e08dab-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:36:44 GMT'
# 2025-04-15 10:36:45,404 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/answer/2025-04.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '767903'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '16e08dac-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-04-15 10:36:45,603 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Tue, 15 Apr 2025 01:36:45 GMT'
#     'ETag': '"0x8DD7BBDFB8D1E38"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '87951291-201e-0097-38a6-ad1580000000'
#     'x-ms-client-request-id': '16e08dac-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:36:44 GMT'
# 2025-04-15 10:36:45,604 - root - INFO - `2025-04.csv` uploaded to blob answer.
# True

# %%
# column_name = "final_answer"
# nan_rows = trace_df_answer[trace_df_answer[column_name].isnull()]
# nan_rows

# %% [markdown]
# ## knowledage

# %%
trace_df_know = trace_df[trace_df["name"] == "HDA_Knowledge"]
trace_df_know = trace_df_know.drop(columns=['input', 'output'])
trace_df_know
# Out:
#                                        id                        timestamp  \
# 107  e5833a6c-be38-4dd9-b9c9-1b53381d6a01 2025-04-14 04:48:40.533000+00:00
#
#               name                   userId                 department_name  \
# 107  HDA_Knowledge  細貝 知宏(Tomohiro Hosokai)  デジタルクリエーション部 デジタルトランスフォーメーションU
#
#     service_category service_name                           question_id  \
# 107            99その他      その他（OA）  0feb4a64-12d6-481a-b3af-0ba7368113c8
#
#     incident_category
# 107                oa

# %%
# know_tmp_fpath = "data/nova/knowledge/tmp.csv"
# trace_df_know.to_csv(know_tmp_fpath, index=False, quoting=1)

# %%
save_data(trace_df_know, 'NOVA', 'knowledge', False)
# Out:
# 2025-04-15 10:37:02,674 - root - INFO - New data: 1
# 2025-04-15 10:37:02,679 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/knowledge/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21894c5e-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:02,791 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '8940'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:14 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF8EFC98F54"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'e69b77cc-d01e-00ac-51a6-ad5024000000'
#     'x-ms-client-request-id': '21894c5e-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:02 GMT'
# 2025-04-15 10:37:02,794 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/knowledge/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21894c5f-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:02,896 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '8940'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:14 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF8EFC98F54"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'a8b8fc11-101e-009c-22a6-adeeeb000000'
#     'x-ms-client-request-id': '21894c5f-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:02 GMT'
# 2025-04-15 10:37:02,899 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/knowledge/2025-04.csv'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21894c60-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:02,983 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '8940'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:14 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF8EFC98F54"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '7b3a076f-701e-001c-5da6-ad11ed000000'
#     'x-ms-client-request-id': '21894c60-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:02 GMT'
# 2025-04-15 10:37:02,985 - root - INFO - save data to temporary place`/tmp/tmp_9a5fg6g/2025-04.csv`.
# 2025-04-15 10:37:02,988 - root - INFO - Find 35 rows data of 2025-04 in Blob.
# 2025-04-15 10:37:02,990 - root - WARNING - Will not overwrite any old data, but remove new data if they are already existing.
# 2025-04-15 10:37:02,991 - root - INFO - remaining 1 new data.
# 2025-04-15 10:37:02,992 - root - INFO - Merged data: 36
# 2025-04-15 10:37:02,993 - root - INFO - Temporary knowledge CSV saved at: /tmp/tmpiat7ecye.csv
# 2025-04-15 10:37:02,995 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/knowledge/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21894c61-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:03,070 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '8940'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:14 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF8EFC98F54"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'dc43dddc-001e-00af-64a6-adb140000000'
#     'x-ms-client-request-id': '21894c61-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:02 GMT'
# 2025-04-15 10:37:03,073 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/knowledge/2025-04.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '9230'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21894c62-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-04-15 10:37:03,149 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Tue, 15 Apr 2025 01:37:03 GMT'
#     'ETag': '"0x8DD7BBE060309EF"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '9741c9cb-e01e-000e-7aa6-ad6a3d000000'
#     'x-ms-client-request-id': '21894c62-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:02 GMT'
# 2025-04-15 10:37:03,151 - root - INFO - `2025-04.csv` uploaded to blob knowledge.
# True

# %% [markdown]
# ## Incident

# %%
trace_df_inc = trace_df[trace_df["name"] == "HDA_Incident"]
trace_df_inc = trace_df_inc.drop(columns=['input', 'output'])
trace_df_inc
# Out:
#                                        id                        timestamp  \
# 0    5a27b0db-bf10-4767-ac2e-76fb65101452 2025-04-14 12:34:00.811000+00:00
# 1    4ce3a271-140e-4296-bef8-59b792e71d67 2025-04-14 11:15:17.146000+00:00
# 2    4d120cf0-d4c0-4dcd-8584-1d30a545fdc8 2025-04-14 11:12:14.148000+00:00
# 3    114fa304-5b3a-44bb-8491-784085e02f03 2025-04-14 10:35:56.393000+00:00
# 4    49598d6a-d508-44a9-8eac-782b2c44b297 2025-04-14 10:29:28.123000+00:00
# ..                                    ...                              ...
# 183  99b849b7-f488-46de-b76a-f9c1c4eae8b2 2025-04-14 00:06:32.438000+00:00
# 185  6a2ea0f8-7378-466b-940a-d11c41a5b7ed 2025-04-14 00:01:59.470000+00:00
# 187  733ef1b8-4773-4655-8c59-a85344af9645 2025-04-14 00:00:55.258000+00:00
# 189  68651edc-7a06-46d1-9edd-d8e67a58df27 2025-04-13 19:43:32.135000+00:00
# 191  9549fd59-3efe-4ec3-9e51-b5eddd6e8e4f 2025-04-13 18:52:41.391000+00:00
#
#              name                     userId  \
# 0    HDA_Incident         黄 凱凱(Kaikai Huang)
# 1    HDA_Incident        飛田 萌里(Moeri Tobita)
# 2    HDA_Incident         川井 一平(Ippei Kawai)
# 3    HDA_Incident    安平 周作(Shusaku Yasuhira)
# 4    HDA_Incident            粟野 亮(Ryo Awano)
# ..            ...                        ...
# 183  HDA_Incident  丸山 泰信(Yoshinobu Maruyama)
# 185  HDA_Incident    那須川 敦(Atsushi Nasukawa)
# 187  HDA_Incident         南 匠(Takumi Minami)
# 189  HDA_Incident      白木 将(Masashi Shiraki)
# 191  HDA_Incident  川上 佳洋(Yoshihiro Kawakami)
#
#                                    department_name service_category  \
# 0    企画統括部 JERA Global Institute 経済・エネルギーモデル開発・分析U             20経理
# 1            グローバル再生可能エネルギー統括部 再生可能エネルギー計画部 再エネ総括U           90IT基盤
# 2                  国内ゼロエミッション火力推進統括部 国内事業計画部 事業計画U             20経理
# 3            グローバル再生可能エネルギー統括部 国内洋上風力事業部 国内洋上風力第一U          10労務・人事
# 4                         最適化統括部 統合ポート戦略部 統合ポート戦略U           90IT基盤
# ..                                             ...              ...
# 183            OM・エンジ戦略統括部 OM・エンジ戦部 西OM・エンジ計部 K推進U           90IT基盤
# 185                          資材調達統括部 購買契約部 購買契約第一U          10労務・人事
# 187                                  ICTマネ部 ICTオペU          10労務・人事
# 189                      販売統括部 需給オペ部 西プラ運用C 西プラ運用U          10労務・人事
# 191                                         最適化統括部          10労務・人事
#
#              service_name question_id incident_category
# 0               会計伝票_経営企画        None          business
# 1        SAP S/4 HANA(共通)        None          business
# 2             JUPITER(経理)        None          business
# 3            労務に関するお問い合わせ        None          business
# 4        SAP S/4 HANA(共通)        None          business
# ..                    ...         ...               ...
# 183      SAP S/4 HANA(共通)        None          business
# 185  SuccessFactors_その他操作        None          business
# 187          労務に関するお問い合わせ        None          business
# 189          労務に関するお問い合わせ        None          business
# 191            CAREERSHIP        None          business
#
# [122 rows x 9 columns]

# %%
# inc_tmp_fpath = "data/nova/incident/tmp.csv"
# trace_df_inc.to_csv(inc_tmp_fpath, index=False, quoting=1)

# %%
save_data(trace_df_inc, 'NOVA', 'incident', False)
# Out:
# 2025-04-15 10:37:08,028 - root - INFO - New data: 122
# 2025-04-15 10:37:08,032 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/incident/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '24ba2b8c-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:08,128 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '248463'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:50 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF904AB54D6"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '257c368d-401e-0091-6fa6-ad263f000000'
#     'x-ms-client-request-id': '24ba2b8c-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:07 GMT'
# 2025-04-15 10:37:08,133 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/incident/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '24ba2b8d-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:08,213 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '248463'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:50 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF904AB54D6"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '406a0380-901e-003b-0ea6-ad0629000000'
#     'x-ms-client-request-id': '24ba2b8d-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:07 GMT'
# 2025-04-15 10:37:08,216 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/incident/2025-04.csv'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '24ba2b8e-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:08,298 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '248463'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:50 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF904AB54D6"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'f25d7b85-001e-0039-61a6-adb891000000'
#     'x-ms-client-request-id': '24ba2b8e-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:07 GMT'
# 2025-04-15 10:37:08,364 - root - INFO - save data to temporary place`/tmp/tmp__vbsr7y/2025-04.csv`.
# 2025-04-15 10:37:08,371 - root - INFO - Find 1018 rows data of 2025-04 in Blob.
# 2025-04-15 10:37:08,372 - root - WARNING - Will not overwrite any old data, but remove new data if they are already existing.
# 2025-04-15 10:37:08,373 - root - INFO - remaining 122 new data.
# 2025-04-15 10:37:08,375 - root - INFO - Merged data: 1140
# 2025-04-15 10:37:08,383 - root - INFO - Temporary incident CSV saved at: /tmp/tmps7qy9o53.csv
# 2025-04-15 10:37:08,386 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/incident/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '24ba2b8f-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:08,464 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '248463'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:06:50 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF904AB54D6"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'cbe24c6e-401e-0075-12a6-ad28a1000000'
#     'x-ms-client-request-id': '24ba2b8f-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:07 GMT'
# 2025-04-15 10:37:08,466 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/incident/2025-04.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '278568'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '24ba2b90-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-04-15 10:37:08,613 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Tue, 15 Apr 2025 01:37:08 GMT'
#     'ETag': '"0x8DD7BBE09447532"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'af13db81-701e-0023-5fa6-add94e000000'
#     'x-ms-client-request-id': '24ba2b90-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:08 GMT'
# 2025-04-15 10:37:08,614 - root - INFO - `2025-04.csv` uploaded to blob incident.
# True

# %% [markdown]
# ## Merge Data

# %%
df_list = [trace_df_answer, trace_df_know, trace_df_inc]
merged_alltrace_df = pd.concat(df_list, ignore_index=True).sort_values(["timestamp"], ascending=False)
merged_alltrace_df
# Out:
#                                        id                        timestamp  \
# 70   5a27b0db-bf10-4767-ac2e-76fb65101452 2025-04-14 12:34:00.811000+00:00
# 71   4ce3a271-140e-4296-bef8-59b792e71d67 2025-04-14 11:15:17.146000+00:00
# 72   4d120cf0-d4c0-4dcd-8584-1d30a545fdc8 2025-04-14 11:12:14.148000+00:00
# 73   114fa304-5b3a-44bb-8491-784085e02f03 2025-04-14 10:35:56.393000+00:00
# 74   49598d6a-d508-44a9-8eac-782b2c44b297 2025-04-14 10:29:28.123000+00:00
# ..                                    ...                              ...
# 189  733ef1b8-4773-4655-8c59-a85344af9645 2025-04-14 00:00:55.258000+00:00
# 67   5ac0fa43-b6c2-4983-8e2b-c16c0a6e867c 2025-04-13 23:54:54.313000+00:00
# 190  68651edc-7a06-46d1-9edd-d8e67a58df27 2025-04-13 19:43:32.135000+00:00
# 68   b29dae2a-096f-448d-80fa-473e4dfc586a 2025-04-13 19:04:29.198000+00:00
# 191  9549fd59-3efe-4ec3-9e51-b5eddd6e8e4f 2025-04-13 18:52:41.391000+00:00
#
#              name                     userId  \
# 70   HDA_Incident         黄 凱凱(Kaikai Huang)
# 71   HDA_Incident        飛田 萌里(Moeri Tobita)
# 72   HDA_Incident         川井 一平(Ippei Kawai)
# 73   HDA_Incident    安平 周作(Shusaku Yasuhira)
# 74   HDA_Incident            粟野 亮(Ryo Awano)
# ..            ...                        ...
# 189  HDA_Incident         南 匠(Takumi Minami)
# 67     HDA_Answer   高梨 敦史(Atsushi Takanashi)
# 190  HDA_Incident      白木 将(Masashi Shiraki)
# 68     HDA_Answer  川上 佳洋(Yoshihiro Kawakami)
# 191  HDA_Incident  川上 佳洋(Yoshihiro Kawakami)
#
#                                    department_name service_category  \
# 70   企画統括部 JERA Global Institute 経済・エネルギーモデル開発・分析U             20経理
# 71           グローバル再生可能エネルギー統括部 再生可能エネルギー計画部 再エネ総括U           90IT基盤
# 72                 国内ゼロエミッション火力推進統括部 国内事業計画部 事業計画U             20経理
# 73           グローバル再生可能エネルギー統括部 国内洋上風力事業部 国内洋上風力第一U          10労務・人事
# 74                        最適化統括部 統合ポート戦略部 統合ポート戦略U           90IT基盤
# ..                                             ...              ...
# 189                                  ICTマネ部 ICTオペU          10労務・人事
# 67                                ICTマネ部 ネットワーク総計U            99その他
# 190                      販売統括部 需給オペ部 西プラ運用C 西プラ運用U          10労務・人事
# 68                                          最適化統括部           90IT基盤
# 191                                         最適化統括部          10労務・人事
#
#          service_name                           question_id incident_category  \
# 70          会計伝票_経営企画                                  None          business
# 71   SAP S/4 HANA(共通)                                  None          business
# 72        JUPITER(経理)                                  None          business
# 73       労務に関するお問い合わせ                                  None          business
# 74   SAP S/4 HANA(共通)                                  None          business
# ..                ...                                   ...               ...
# 189      労務に関するお問い合わせ                                  None          business
# 67            その他（OA）  19b7bb4e-fb00-4b9c-8c38-f38cb18ab88a                oa
# 190      労務に関するお問い合わせ                                  None          business
# 68        iPhone/iPad  fdbc7448-dfd1-4986-a881-a7d116ef60e9                oa
# 191        CAREERSHIP                                  None          business
#
#                                               question  \
# 70                                                 NaN
# 71                                                 NaN
# 72                                                 NaN
# 73                                                 NaN
# 74                                                 NaN
# ..                                                 ...
# 189                                                NaN
# 67                     Wrikeで外部ユーザーを登録するときはどうやって登録するの？
# 190                                                NaN
# 68   JERA Wi-Fiの設定時の STEP２ タップ時に「接続がプライベートではありません」と...
# 191                                                NaN
#
#                                           final_answer
# 70                                                 NaN
# 71                                                 NaN
# 72                                                 NaN
# 73                                                 NaN
# 74                                                 NaN
# ..                                                 ...
# 189                                                NaN
# 67   提供されたデータには、Wrikeで外部ユーザーを登録する具体的な手順は記載されていません。W...
# 190                                                NaN
# 68   JERA Wi-Fiの設定時に「接続がプライベートではありません」と表示される問題については...
# 191                                                NaN
#
# [192 rows x 11 columns]

# %%
save_data(merged_alltrace_df, 'NOVA', 'alltrace', False)
# Out:
# 2025-04-15 10:37:15,103 - root - INFO - New data: 192
# 2025-04-15 10:37:15,106 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '28f1848e-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:15,215 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '941011'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:10:05 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF9792D7C7B"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4e8fa55f-901e-0014-08a6-ad0be2000000'
#     'x-ms-client-request-id': '28f1848e-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:14 GMT'
# 2025-04-15 10:37:15,218 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '28f1848f-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:15,311 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '941011'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:10:05 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF9792D7C7B"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'bd3cdc5e-801e-0037-51a6-ad9121000000'
#     'x-ms-client-request-id': '28f1848f-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:15 GMT'
# 2025-04-15 10:37:15,313 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '28f18490-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:15,435 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '941011'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:10:05 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF9792D7C7B"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'bae2a64c-e01e-0043-42a6-ada5d1000000'
#     'x-ms-client-request-id': '28f18490-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:14 GMT'
# 2025-04-15 10:37:15,578 - root - INFO - save data to temporary place`/tmp/tmpy6f3o2op/2025-04.csv`.
# 2025-04-15 10:37:15,595 - root - INFO - Find 1631 rows data of 2025-04 in Blob.
# 2025-04-15 10:37:15,598 - root - WARNING - Will not overwrite any old data, but remove new data if they are already existing.
# 2025-04-15 10:37:15,601 - root - INFO - remaining 192 new data.
# 2025-04-15 10:37:15,604 - root - INFO - Merged data: 1823
# 2025-04-15 10:37:15,619 - root - INFO - Temporary alltrace CSV saved at: /tmp/tmpbn171zw4.csv
# 2025-04-15 10:37:15,621 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '28f18491-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-15 10:37:15,698 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '941011'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 14 Apr 2025 02:10:05 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD7AF9792D7C7B"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '5b14f2e7-601e-00a9-3ca6-ad82ff000000'
#     'x-ms-client-request-id': '28f18491-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:15 GMT'
# 2025-04-15 10:37:15,701 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1062519'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '28f18492-199a-11f0-8c4c-13849cff4d4f'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-04-15 10:37:15,901 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Tue, 15 Apr 2025 01:37:15 GMT'
#     'ETag': '"0x8DD7BBE0D9C57FA"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '17ee3a53-101e-0035-60a6-ad2f99000000'
#     'x-ms-client-request-id': '28f18492-199a-11f0-8c4c-13849cff4d4f'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 15 Apr 2025 01:37:15 GMT'
# 2025-04-15 10:37:15,903 - root - INFO - `2025-04.csv` uploaded to blob alltrace.
# True

# %%
# for month, group in merged_alltrace_df.groupby('year_month'):
#     group.drop(columns=['year_month'], inplace=True)  # optional
#     fpath = f'data/nova/monthly/alltrace/{month}.csv'
#     if os.path.exists(fpath):
#         logger.info(f"{fpath} already exisiting")
#         old_df = pd.read_csv(fpath)
#         logger.info(f"Old data: {len(old_df)}")
#         merged_df = pd.concat([old_df, group], ignore_index=True).sort_values(["timestamp"], ascending=False)

#         all_exist = group['id'].isin(old_df['id']).all()
#         if all_exist:
#             logger.warning(f"all new data already existing, no need to save")
#         else:
#             duplicates = merged_df[merged_df.duplicated('id', keep=False)]
#             # Print the duplicate rows (if any)
#             logger.warning(f"{len(duplicates)} data already existing")

#             merged_df = merged_df.drop_duplicates(["id"], keep='first')
#             logger.info(f"removed duplicated data")
#             logger.info(f"New data: {len(merged_df)}")
#             logger.info(f"save new {month} data to {fpath}")


#             # merged_df.to_csv(fpath, index=False, quoting=1)
#     else:
#         logger.info(f"save new month data to {fpath}")
#         logger.info(f"New data: {len(group)}")


#         # group.to_csv(fpath, index=False, quoting=1)
        
#     # upload_to_blob("NOVA", "alltrace", fpath, overwrite = True)

# %%
# import glob

# # Folder containing the CSV files
# folder_path = './data/nova/monthly/answer'  # change this to your folder path

# # Get list of all CSV files in the folder
# csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# # Folder containing the CSV files
# folder_path = './data/nova/monthly/incident'  # change this to your folder path

# # Get list of all CSV files in the folder
# csv_files += glob.glob(os.path.join(folder_path, '*.csv'))

# # Folder containing the CSV files
# folder_path = './data/nova/monthly/knowledge'  # change this to your folder path

# # Get list of all CSV files in the folder
# csv_files += glob.glob(os.path.join(folder_path, '*.csv'))


# print(csv_files)

# # Read and merge all CSV files
# df_list = [pd.read_csv(file) for file in sorted(csv_files)]
# merged_all_df = pd.concat(df_list, ignore_index=True).sort_values(["timestamp"], ascending=False)

# # Display merged DataFrame
# merged_all_df

# %%
# merged_trace_df = conver_to_yyyymm(merged_all_df, 'timestamp')
# # merged_trace_df

# for month, group in merged_trace_df.groupby('year_month'):
#     group.drop(columns=['year_month'], inplace=True)  # optional
#     fpath = f'data/nova/monthly/alltrace/{month}.csv'
#     if os.path.exists(fpath):
#         logger.info(f"{fpath} already exisiting")
#         old_df = pd.read_csv(fpath)
#         merged_df = pd.concat([old_df, group], ignore_index=True).sort_values(["timestamp"], ascending=False)
#         merged_df = merged_df.drop_duplicates(["id"], keep='first')
#         logger.info(f"save new {month} data to {fpath}")
#         merged_df.to_csv(fpath, index=False, quoting=1)
#     else:
#         logger.info(f"save new month data to {fpath}")
#         group.to_csv(fpath, index=False, quoting=1)
        
#     upload_to_blob("NOVA", "alltrace", fpath, overwrite = True)
# Out:
# 2025-04-11 12:24:27,249 - root - INFO - data/nova/monthly/alltrace/2025-03.csv already exisiting
# 2025-04-11 12:24:27,296 - root - INFO - save new 2025-03 data to data/nova/monthly/alltrace/2025-03.csv
# 2025-04-11 12:24:27,324 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-03.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '79312df0-1684-11f0-9bc0-6df91223bea8'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-11 12:24:27,529 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '2824622'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Thu, 10 Apr 2025 08:32:18 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD780A34D7E65D"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'e2e53a94-e01e-006c-6991-aaa81a000000'
#     'x-ms-client-request-id': '79312df0-1684-11f0-9bc0-6df91223bea8'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Fri, 11 Apr 2025 03:24:27 GMT'
# 2025-04-11 12:24:27,532 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-03.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2824622'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '79312df1-1684-11f0-9bc0-6df91223bea8'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-04-11 12:24:28,504 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Fri, 11 Apr 2025 03:24:28 GMT'
#     'ETag': '"0x8DD78A85E164089"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '716f4e38-701e-000c-5491-aad485000000'
#     'x-ms-client-request-id': '79312df1-1684-11f0-9bc0-6df91223bea8'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Fri, 11 Apr 2025 03:24:28 GMT'
# 2025-04-11 12:24:28,512 - root - INFO - data/nova/monthly/alltrace/2025-04.csv already exisiting
# 2025-04-11 12:24:28,559 - root - INFO - save new 2025-04 data to data/nova/monthly/alltrace/2025-04.csv
# 2025-04-11 12:24:28,574 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '79312df2-1684-11f0-9bc0-6df91223bea8'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-04-11 12:24:28,687 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '785566'
#     'Content-Type': 'application/octet-stream'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Thu, 10 Apr 2025 08:32:19 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DD780A35046E20"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '730fbcbf-501e-0034-0691-aa7045000000'
#     'x-ms-client-request-id': '79312df2-1684-11f0-9bc0-6df91223bea8'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'Date': 'Fri, 11 Apr 2025 03:24:28 GMT'
# 2025-04-11 12:24:28,691 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://hdabeproddata.blob.core.windows.net/alltrace/2025-04.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '842343'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.0 Python/3.10.4 (Linux-5.15.146.1-microsoft-standard-WSL2-x86_64-with-glibc2.35)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '79312df3-1684-11f0-9bc0-6df91223bea8'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# `2025-03.csv` uploaded to blob alltrace.
# 2025-04-11 12:24:29,061 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Fri, 11 Apr 2025 03:24:29 GMT'
#     'ETag': '"0x8DD78A85E6B58F8"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '6368ad55-a01e-007d-4291-aa32ae000000'
#     'x-ms-client-request-id': '79312df3-1684-11f0-9bc0-6df91223bea8'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Fri, 11 Apr 2025 03:24:28 GMT'
# `2025-04.csv` uploaded to blob alltrace.
